# %% [markdown]
# <a href="https://colab.research.google.com/github/TharuWitharana/mobilenetv1/blob/main/TrainedFinalModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow
# !pip install tensorflow-addons
# !pip install vit-keras
# !pip install typeguard
# !pip install ml-dtypes
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.6)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 6.6 MB/s eta 0:00:00
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.0
#     Uninstalling typeguard-4.4.0:
#       Successfully uninstalled typeguard-4.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.4.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3
# Collecting vit-keras
#   Downloading vit_keras-0.1.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from vit-keras) (1.13.1)
# Collecting validators (from vit-keras)
#   Downloading validators-0.34.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from scipy->vit-keras) (1.26.4)
# Downloading vit_keras-0.1.2-py3-none-any.whl (24 kB)
# Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: validators, vit-keras
# Successfully installed validators-0.34.0 vit-keras-0.1.2
# Requirement already satisfied: typeguard in /usr/local/lib/python3.10/dist-packages (2.13.3)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (0.4.1)
# Requirement already satisfied: numpy>1.20 in /usr/local/lib/python3.10/dist-packages (from ml-dtypes) (1.26.4)

# %%
import os
import numpy as np
import random
import shutil
import warnings
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from termcolor import colored
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Dense, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau , CSVLogger
from keras.utils import plot_model
tf.get_logger().setLevel('ERROR')

# %%
# Define the path to the directory containing your dataset
# This is the directory where your dataset is stored in Google Drive
directory_path = '/content/drive/MyDrive/SplittedNovelDatasetv3'

# List all files in the directory
# The os.listdir() function returns a list of all files and directories in the specified path
files = os.listdir(directory_path)

# Print the list of files
# This will display the names of all the files in the specified directory
print(files)
# Out:
# ['train', 'test', 'validation']

# %%
# Set a random seed value for reproducibility
SEED = 42

# Seed the random number generator in NumPy
# Setting a seed ensures that the random numbers generated are the same every time the code is run,
# which is useful for reproducibility in experiments and debugging
np.random.seed(SEED)

# %%
# Insert the Dataset path here
# Define the path to the training dataset directory
train_path = '/content/drive/MyDrive/SplittedNovelDatasetv3/train'

# Define the path to the validation dataset directory
val_path = '/content/drive/MyDrive/SplittedNovelDatasetv3/validation'

# Define the path to the testing dataset directory
test_path = '/content/drive/MyDrive/SplittedNovelDatasetv3/test'

# %%
# Set the size of the images to be used in the model (e.g., 224x224 pixels)
IMAGE_SIZE = 224

# Set the number of samples to process before updating the model's weights
BATCH_SIZE = 32

# Set the number of epochs for training the model
EPOCHS = 100

# Set the learning rate for the optimizer (controls how much to change the model in response to the estimated error each time the model weights are updated)
LEARNING_RATE = 1e-4

# Set the width multiplier for the MobileNet architecture (scales the width of the network by this factor)
WIDTH_MULTIPLIER = 1

# %%
# Create an ImageDataGenerator instance for training data with various augmentations
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,                   # Normalize pixel values to [0, 1]
    rotation_range=360,               # Randomly rotate images by up to 360 degrees
    height_shift_range=0.1,           # Randomly shift images vertically by up to 10% of the height
    shear_range=0.1,                  # Apply random shearing transformations
    zoom_range=0.1,                   # Apply random zoom
    fill_mode='nearest',              # Fill in newly created pixels with the nearest pixel value
    brightness_range=[0.8, 1.4],     # Randomly change the brightness of images
    vertical_flip=True,               # Randomly flip images vertically
    horizontal_flip=True)             # Randomly flip images horizontally

# Create an ImageDataGenerator instance for validation data with only normalization
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255)                   # Normalize pixel values to [0, 1]

# Create an ImageDataGenerator instance for test data with only normalization
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255)                   # Normalize pixel values to [0, 1]

# Create a data generator for training with augmented images
train_generator = train_datagen.flow_from_directory(
    train_path,                       # Path to the training data
    target_size=(IMAGE_SIZE, IMAGE_SIZE),  # Resize images to the specified size
    batch_size=BATCH_SIZE,            # Number of images to return in each batch
    class_mode='categorical')         # Use categorical labels (one-hot encoded)

# Create a data generator for validation data with normalization only
validation_generator = val_datagen.flow_from_directory(
    val_path,                         # Path to the validation data
    target_size=(IMAGE_SIZE, IMAGE_SIZE),  # Resize images to the specified size
    batch_size=BATCH_SIZE,            # Number of images to return in each batch
    class_mode='categorical')         # Use categorical labels (one-hot encoded)

# Create a data generator for test data with normalization only, no shuffling
test_generator = test_datagen.flow_from_directory(
    test_path,                        # Path to the test data
    target_size=(IMAGE_SIZE, IMAGE_SIZE),  # Resize images to the specified size
    batch_size=BATCH_SIZE,            # Number of images to return in each batch
    class_mode='categorical',         # Use categorical labels (one-hot encoded)
    shuffle=False)                    # Do not shuffle the test data
# Out:
# Found 1111 images belonging to 8 classes.
# Found 239 images belonging to 8 classes.
# Found 242 images belonging to 8 classes.

# %%
def num_of_classes(folder_dir, folder_name):
    """
    Print the number of classes in a specified directory.

    Parameters:
    folder_dir (str): The path to the directory containing subdirectories of classes.
    folder_name (str): The name of the folder for display purposes.
    """
    # List all subdirectory names (class names) in the specified directory
    classes = [class_name for class_name in os.listdir(folder_dir)]

    # Print the number of classes found in the directory with bold blue text
    print(colored(f'number of classes in {folder_name} folder : {len(classes)}', 'blue', attrs=['bold']))

# %%
# Print the number of classes in the training dataset
num_of_classes(train_path, 'train')

# Print the number of classes in the validation dataset
num_of_classes(val_path, 'validation')

# Print the number of classes in the test dataset
num_of_classes(test_path, 'test')
# Out:
# number of classes in train folder : 8
# number of classes in validation folder : 8
# number of classes in test folder : 8

# %%
# Get the class names from the training data directory
classes = [class_name for class_name in os.listdir(train_path)]

# Count the number of samples in each class directory
count = [len(os.listdir(os.path.join(train_path, class_name))) for class_name in classes]

# Convert class names to integers if they are in string format and sort them
# This assumes class names can be converted to integers for sorting purposes
sorted_classes = sorted(classes, key=int)
sorted_count = [count[classes.index(class_name)] for class_name in sorted_classes]

# Plot the sorted class counts
plt.figure(figsize=(15, 4))  # Set the figure size for the plot

# Create a bar plot with seaborn
ax = sns.barplot(x=sorted_classes, y=sorted_count, color='navy')

# Adjust x-axis tick labels to be horizontal (no rotation)
plt.xticks(rotation=0)

# Add labels on top of the bars
for container in ax.containers:
    ax.bar_label(container)

# Set the plot title and axis labels
plt.title('Number of samples per label', fontsize=25, fontweight='bold')
plt.xlabel('Labels', fontsize=15)
plt.ylabel('Counts', fontsize=15)

# Set y-axis ticks with a step of 10
plt.yticks(np.arange(0, max(sorted_count) + 10, 10))

# Display the plot
plt.show()

# %%
# Function to create a DataFrame from images in a given folder
def create_df(folder_path):
    all_images = []  # Initialize an empty list to store image paths and labels

    # Iterate over each class directory
    for class_name in classes:
        class_path = os.path.join(folder_path, class_name)  # Path to the current class directory

        # List all files in the current class directory and create a list of tuples (file_path, label)
        all_images.extend([(os.path.join(class_path, file_name), class_name) for file_name in os.listdir(class_path)])

    # Create a DataFrame from the list of tuples with columns 'file_path' and 'label'
    df = pd.DataFrame(all_images, columns=['file_path', 'label'])
    return df  # Return the DataFrame

# Create DataFrames for training, validation, and test datasets
train_df = create_df(train_path)
validation_df = create_df(val_path)
test_df = create_df(test_path)

# %%
# Ensure that train_df is sorted by label
train_df_sorted = train_df.copy()  # Create a copy of the train DataFrame to avoid modifying the original
train_df_sorted['label'] = train_df_sorted['label'].astype(int)  # Convert labels to integers if they are in string format
train_df_sorted = train_df_sorted.sort_values(by='label').reset_index(drop=True)  # Sort by label and reset the index

# Create a DataFrame containing only one image per label
df_unique = train_df_sorted.drop_duplicates(subset=["label"]).reset_index(drop=True)

# Plot a selection of images from the dataset
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(12, 6), subplot_kw={'xticks': [], 'yticks': []})
# Create a grid of subplots (2 rows x 6 columns) for displaying images

for i, ax in enumerate(axes.flat):
    if i < len(df_unique):  # Ensure the index is within the bounds of df_unique
        img = plt.imread(df_unique.file_path[i])  # Read the image from the file path
        ax.imshow(img)  # Display the image
        ax.set_title(df_unique.label[i], fontsize=12)  # Set the title of the subplot to the label of the image

plt.tight_layout(pad=0.5)  # Adjust the layout to prevent overlap
plt.show()  # Display the plot

# %%
# Import the MobileNet model from TensorFlow's Keras applications
mobile = tf.keras.applications.MobileNet()

# Explanation:
# This line initializes the MobileNet model with default parameters.
# MobileNet is a lightweight neural network designed for mobile and edge devices,
# providing a good trade-off between speed and accuracy for image classification tasks.
# By default, this model is initialized with pre-trained weights from ImageNet.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Print the summary of the MobileNet model
mobile.summary()

# Explanation:
# This function call outputs a detailed summary of the MobileNet model architecture.
# It includes information about the layers, their output shapes, the number of parameters
# (both trainable and non-trainable), and the overall model structure.
# This summary helps in understanding the model's design and verifying the configuration.
# Out:
# Model: "mobilenet_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1 (Conv2D)                       │ (None, 112, 112, 32)        │             864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1_bn (BatchNormalization)        │ (None, 112, 112, 32)        │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1_relu (ReLU)                    │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1 (DepthwiseConv2D)          │ (None, 112, 112, 32)        │             288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1_bn (BatchNormalization)    │ (None, 112, 112, 32)        │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_1_relu (ReLU)                │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1 (Conv2D)                   │ (None, 112, 112, 64)        │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1_bn (BatchNormalization)    │ (None, 112, 112, 64)        │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_1_relu (ReLU)                │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_2 (ZeroPadding2D)           │ (None, 113, 113, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2 (DepthwiseConv2D)          │ (None, 56, 56, 64)          │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2_bn (BatchNormalization)    │ (None, 56, 56, 64)          │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_2_relu (ReLU)                │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2 (Conv2D)                   │ (None, 56, 56, 128)         │           8,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2_bn (BatchNormalization)    │ (None, 56, 56, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_2_relu (ReLU)                │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3 (DepthwiseConv2D)          │ (None, 56, 56, 128)         │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3_bn (BatchNormalization)    │ (None, 56, 56, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_3_relu (ReLU)                │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3 (Conv2D)                   │ (None, 56, 56, 128)         │          16,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3_bn (BatchNormalization)    │ (None, 56, 56, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_3_relu (ReLU)                │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_4 (ZeroPadding2D)           │ (None, 57, 57, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4 (DepthwiseConv2D)          │ (None, 28, 28, 128)         │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4_bn (BatchNormalization)    │ (None, 28, 28, 128)         │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_4_relu (ReLU)                │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4 (Conv2D)                   │ (None, 28, 28, 256)         │          32,768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4_bn (BatchNormalization)    │ (None, 28, 28, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_4_relu (ReLU)                │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5 (DepthwiseConv2D)          │ (None, 28, 28, 256)         │           2,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5_bn (BatchNormalization)    │ (None, 28, 28, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_5_relu (ReLU)                │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5 (Conv2D)                   │ (None, 28, 28, 256)         │          65,536 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5_bn (BatchNormalization)    │ (None, 28, 28, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_5_relu (ReLU)                │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_6 (ZeroPadding2D)           │ (None, 29, 29, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6 (DepthwiseConv2D)          │ (None, 14, 14, 256)         │           2,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6_bn (BatchNormalization)    │ (None, 14, 14, 256)         │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_6_relu (ReLU)                │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6 (Conv2D)                   │ (None, 14, 14, 512)         │         131,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_6_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7 (DepthwiseConv2D)          │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_7_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7 (Conv2D)                   │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_7_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8 (DepthwiseConv2D)          │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_8_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8 (Conv2D)                   │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_8_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9 (DepthwiseConv2D)          │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_9_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9 (Conv2D)                   │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9_bn (BatchNormalization)    │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_9_relu (ReLU)                │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10 (DepthwiseConv2D)         │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_10_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10 (Conv2D)                  │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_10_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11 (DepthwiseConv2D)         │ (None, 14, 14, 512)         │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_11_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11 (Conv2D)                  │ (None, 14, 14, 512)         │         262,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11_bn (BatchNormalization)   │ (None, 14, 14, 512)         │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_11_relu (ReLU)               │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pad_12 (ZeroPadding2D)          │ (None, 15, 15, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12 (DepthwiseConv2D)         │ (None, 7, 7, 512)           │           4,608 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12_bn (BatchNormalization)   │ (None, 7, 7, 512)           │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_12_relu (ReLU)               │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12 (Conv2D)                  │ (None, 7, 7, 1024)          │         524,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12_bn (BatchNormalization)   │ (None, 7, 7, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_12_relu (ReLU)               │ (None, 7, 7, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13 (DepthwiseConv2D)         │ (None, 7, 7, 1024)          │           9,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13_bn (BatchNormalization)   │ (None, 7, 7, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_dw_13_relu (ReLU)               │ (None, 7, 7, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_13 (Conv2D)                  │ (None, 7, 7, 1024)          │       1,048,576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_13_bn (BatchNormalization)   │ (None, 7, 7, 1024)          │           4,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_pw_13_relu (ReLU)               │ (None, 7, 7, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1, 1, 1024)          │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1, 1, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_preds (Conv2D)                  │ (None, 1, 1, 1000)          │       1,025,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_2 (Reshape)                  │ (None, 1000)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ predictions (Activation)             │ (None, 1000)                │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,253,864 (16.23 MB)
#  Trainable params: 4,231,976 (16.14 MB)
#  Non-trainable params: 21,888 (85.50 KB)

# %%
# Load the pre-trained MobileNet model
mobile = MobileNet()

# %%
# Take the output from the fifth-to-last layer of MobileNet
x = mobile.layers[-5].output


# Reshape the output to be 1D tensor with 1024 elements
x = Reshape(target_shape=(1024,))(x)


# Add a dense layer with 8 units(number of classes) and softmax activation for classification
output = Dense(units=8, activation='softmax')(x)

# %%
# Create a new model with the same input as MobileNet but with the new output layer
model = Model(inputs=mobile.input, outputs=output)

# Freeze all layers except the last 22 layers
for layer in model.layers[:-22]:
    layer.trainable = False

# %%
# Define the directory where model progress and logs will be saved
save_dir = '/content/drive/MyDrive/fypmodel/MobilenetV1/new4'

# Create the main directory if it doesn't exist
os.makedirs(save_dir, exist_ok=True)

# Define and create subdirectories for saving model weights and logs
weights_dir = os.path.join(save_dir, 'weights')
os.makedirs(weights_dir, exist_ok=True)  # Create directory for saving model weights

logs_dir = os.path.join(save_dir, 'logs')
os.makedirs(logs_dir, exist_ok=True)  # Create directory for saving logs

# %%
# Define the ModelCheckpoint callback to save model weights during training
model_checkpoint_callback = ModelCheckpoint(
    # Specify the file path where the weights will be saved.
    # The file name includes an epoch placeholder for versioning.
    # The extension '.weights.h5' is required when 'save_weights_only=True'.
    filepath=os.path.join(weights_dir, 'MobileNet_weights-{epoch:02d}.weights.h5'),

    # Set this to True to save only the weights of the model, not the entire model.
    save_weights_only=True,

    # Monitor the 'val_loss' during training.
    # The checkpoint will be based on the validation loss.
    monitor='val_loss',

    # Define the mode for the monitored metric. 'min' means the checkpoint will be updated
    # only when the validation loss decreases, indicating better performance.
    mode='min',

    # Save only the best weights (those with the lowest validation loss).
    # If set to False, the weights will be saved at the end of each epoch.
    save_best_only=True,

    # Verbosity mode to display messages during the training process.
    # 1 will show the progress messages for saving weights.
    verbose=1
)

# %%
# prompt: weights have not saved on above directory

# The provided code already includes ModelCheckpoint callback to save the model weights.
# The weights are saved in the directory '/content/drive/MyDrive/fypmodel/MobilenetV1/new2/weights'
# The issue might be with the directory path or the filename.

# Check if the directory exists and is accessible
print(f"Weights directory: {weights_dir}")
if os.path.exists(weights_dir):
    print("Weights directory exists.")
    # List files in the weights directory to confirm weights are saved
    weight_files = os.listdir(weights_dir)
    if weight_files:
        print("Weight files found:")
        for file in weight_files:
          print(file)
    else:
        print("No weight files found in the directory.")
else:
    print("Weights directory does not exist.")


# If the directory or files are not found, double-check the save_dir variable.
# Also, ensure that Google Drive is properly mounted and you have write access to the specified directory.
# Out:
# Weights directory: /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights
# Weights directory exists.
# Weight files found:
# MobileNet_weights-08.weights.h5
# MobileNet_weights-18.weights.h5
# MobileNet_weights-20.weights.h5
# MobileNet_weights-32.weights.h5
# MobileNet_weights-44.weights.h5
# MobileNet_weights-07.weights.h5
# MobileNet_weights-10.weights.h5
# MobileNet_weights-14.weights.h5
# MobileNet_weights-24.weights.h5
# MobileNet_weights-26.weights.h5
# MobileNet_weights-28.weights.h5
# MobileNet_weights-42.weights.h5
# MobileNet_weights-03.weights.h5
# MobileNet_weights-06.weights.h5
# MobileNet_weights-05.weights.h5
# MobileNet_weights-09.weights.h5
# MobileNet_weights-11.weights.h5
# MobileNet_weights-12.weights.h5
# MobileNet_weights-16.weights.h5
# MobileNet_weights-01.weights.h5

# %%
# Define the ReduceLROnPlateau callback to adjust the learning rate based on validation loss
reduce_lr_callback = ReduceLROnPlateau(
    # Metric to monitor for triggering the learning rate reduction
    monitor='val_loss',

    # Factor by which the learning rate will be reduced.
    # New learning rate = current learning rate * factor
    factor=0.1,

    # Number of epochs with no improvement after which learning rate will be reduced.
    # If the validation loss does not improve for 'patience' epochs, the learning rate is reduced.
    patience=5,

    # Verbosity mode. If set to 1, messages will be displayed when the learning rate is reduced.
    verbose=1
)

# %%
from keras.callbacks import CSVLogger, EarlyStopping

# Define the CSVLogger callback to log training progress to a CSV file
csv_logger_callback = CSVLogger(
    # File path where the training log will be saved
    os.path.join(logs_dir, 'training_log.csv')
)

# Define the EarlyStopping callback to halt training when the validation loss stops improving
early_stopping_callback = EarlyStopping(
    # Metric to monitor for early stopping. Training will stop if 'val_loss' does not improve.
    monitor='val_loss',

    # Number of epochs with no improvement in the monitored metric after which training will stop.
    patience=20,

    # Verbosity mode. If set to 1, messages will be displayed when early stopping is triggered.
    verbose=1,

    # Whether to restore model weights from the epoch with the best value of the monitored metric.
    # If True, the model weights from the epoch with the lowest validation loss will be restored.
    restore_best_weights=True
)

# %%
# Define a list of callbacks to be used during model training
callbacks = [
    # Callback to save model weights during training, with the best weights saved based on validation loss
    model_checkpoint_callback,

    # Callback to reduce the learning rate when the validation loss plateaus
    reduce_lr_callback,

    # Callback to log training progress to a CSV file for later analysis
    csv_logger_callback,

    # Callback to stop training early if validation loss does not improve, restoring the best weights
    early_stopping_callback
]

# %%
# Create a MobileNetV1 model with a specified width multiplier
base_model = MobileNet(
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3),  # Input shape of the images
    alpha=WIDTH_MULTIPLIER,                   # Width multiplier to adjust model size
    include_top=False,                        # Exclude the top (fully connected) layers
    pooling='avg'                             # Use average pooling to reduce the feature maps
)

# Create a Sequential model by stacking the base MobileNetV1 model and a dense layer
model = tf.keras.Sequential([
    base_model,                              # Base MobileNetV1 model for feature extraction
    Dense(8, activation='softmax')           # Dense layer for classification into 8 classes
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Compile the model
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),  # Optimizer with a specified learning rate
    loss=tf.keras.losses.CategoricalCrossentropy(),  # Loss function for multi-class classification
    metrics=[tf.keras.metrics.CategoricalAccuracy()]  # Metric to evaluate the accuracy of the model
)

# %%
from PIL import ImageFile

# Set Pillow to ignore truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Train the model
history = model.fit(
    train_generator,  # Training data generator
    validation_data=validation_generator,  # Validation data generator
    epochs=50,  # Number of epochs to train the model
    steps_per_epoch=train_generator.samples // BATCH_SIZE,  # Number of batches per epoch for training
    validation_steps=validation_generator.samples // BATCH_SIZE,  # Number of batches per epoch for validation
    callbacks=callbacks  # List of callback functions to apply during training
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.5289 - loss: 1.4333
# Epoch 1: val_loss improved from inf to 3.85830, saving model to /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-01.weights.h5
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 616s 15s/step - categorical_accuracy: 0.5344 - loss: 1.4170 - val_categorical_accuracy: 0.2366 - val_loss: 3.8583 - learning_rate: 1.0000e-04
# Epoch 2/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:14 8s/step - categorical_accuracy: 0.8125 - loss: 0.4685
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_loss did not improve from 3.85830
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - categorical_accuracy: 0.8125 - loss: 0.4685 - val_categorical_accuracy: 0.3333 - val_loss: 4.0224 - learning_rate: 1.0000e-04
# Epoch 3/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - categorical_accuracy: 0.9365 - loss: 0.2563
# Epoch 3: val_loss improved from 3.85830 to 1.78270, saving model to /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-03.weights.h5
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 361s 10s/step - categorical_accuracy: 0.9367 - loss: 0.2552 - val_categorical_accuracy: 0.4241 - val_loss: 1.7827 - learning_rate: 1.0000e-04
# Epoch 4/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:28 8s/step - categorical_accuracy: 0.9688 - loss: 0.0787
# Epoch 4: val_loss improved from 1.78270 to 1.06269, saving model to /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-04.weights.h5
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - categorical_accuracy: 0.9688 - loss: 0.0787 - val_categorical_accuracy: 0.6667 - val_loss: 1.0627 - learning_rate: 1.0000e-04
# Epoch 5/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9644 - loss: 0.1466
# Epoch 5: val_loss improved from 1.06269 to 0.84659, saving model to /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-05.weights.h5
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 333s 9s/step - categorical_accuracy: 0.9643 - loss: 0.1463 - val_categorical_accuracy: 0.6830 - val_loss: 0.8466 - learning_rate: 1.0000e-04
# Epoch 6/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:31 6s/step - categorical_accuracy: 0.9688 - loss: 0.1007
# Epoch 6: val_loss improved from 0.84659 to 0.68334, saving model to /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-06.weights.h5
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - categorical_accuracy: 0.9688 - loss: 0.1007 - val_categorical_accuracy: 0.9333 - val_loss: 0.6833 - learning_rate: 1.0000e-04
# Epoch 7/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - categorical_accuracy: 0.9657 - loss: 0.1186
# Epoch 7: val_loss improved from 0.68334 to 0.43610, saving model to /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-07.weights.h5
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 340s 9s/step - categorical_accuracy: 0.9660 - loss: 0.1180 - val_categorical_accuracy: 0.8616 - val_loss: 0.4361 - learning_rate: 1.0000e-04
# Epoch 8/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:16 8s/step - categorical_accuracy: 0.9375 - loss: 0.1559
# Epoch 8: val_loss improved from 0.43610 to 0.06768, saving model to /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-08.weights.h5
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 14s 200ms/step - categorical_accuracy: 0.9375 - loss: 0.1559 - val_categorical_accuracy: 1.0000 - val_loss: 0.0677 - learning_rate: 1.0000e-04
# Epoch 9/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9836 - loss: 0.0764
# Epoch 9: val_loss did not improve from 0.06768
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 360s 9s/step - categorical_accuracy: 0.9835 - loss: 0.0764 - val_categorical_accuracy: 0.9420 - val_loss: 0.2085 - learning_rate: 1.0000e-04
# Epoch 10/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:34 8s/step - categorical_accuracy: 1.0000 - loss: 0.0181
# Epoch 10: val_loss did not improve from 0.06768
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0181 - val_categorical_accuracy: 0.9333 - val_loss: 0.1222 - learning_rate: 1.0000e-04
# Epoch 11/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9885 - loss: 0.0575
# Epoch 11: val_loss did not improve from 0.06768
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 323s 9s/step - categorical_accuracy: 0.9886 - loss: 0.0574 - val_categorical_accuracy: 0.9509 - val_loss: 0.2004 - learning_rate: 1.0000e-04
# Epoch 12/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:38 8s/step - categorical_accuracy: 0.9688 - loss: 0.0702
# Epoch 12: val_loss improved from 0.06768 to 0.04013, saving model to /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-12.weights.h5
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 12s 103ms/step - categorical_accuracy: 0.9688 - loss: 0.0702 - val_categorical_accuracy: 1.0000 - val_loss: 0.0401 - learning_rate: 1.0000e-04
# Epoch 13/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9896 - loss: 0.0448
# Epoch 13: val_loss did not improve from 0.04013
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 378s 9s/step - categorical_accuracy: 0.9895 - loss: 0.0449 - val_categorical_accuracy: 0.9688 - val_loss: 0.1453 - learning_rate: 1.0000e-04
# Epoch 14/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:18 8s/step - categorical_accuracy: 1.0000 - loss: 0.0362
# Epoch 14: val_loss did not improve from 0.04013
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0362 - val_categorical_accuracy: 0.9333 - val_loss: 0.2004 - learning_rate: 1.0000e-04
# Epoch 15/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9896 - loss: 0.0445
# Epoch 15: val_loss did not improve from 0.04013
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 323s 9s/step - categorical_accuracy: 0.9896 - loss: 0.0443 - val_categorical_accuracy: 0.9688 - val_loss: 0.1394 - learning_rate: 1.0000e-04
# Epoch 16/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:11 8s/step - categorical_accuracy: 1.0000 - loss: 0.0550
# Epoch 16: val_loss improved from 0.04013 to 0.00728, saving model to /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-16.weights.h5
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 104ms/step - categorical_accuracy: 1.0000 - loss: 0.0550 - val_categorical_accuracy: 1.0000 - val_loss: 0.0073 - learning_rate: 1.0000e-04
# Epoch 17/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - categorical_accuracy: 0.9932 - loss: 0.0337
# Epoch 17: val_loss did not improve from 0.00728
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 334s 9s/step - categorical_accuracy: 0.9931 - loss: 0.0338 - val_categorical_accuracy: 0.9688 - val_loss: 0.1273 - learning_rate: 1.0000e-04
# Epoch 18/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:37 7s/step - categorical_accuracy: 1.0000 - loss: 0.0403
# Epoch 18: val_loss did not improve from 0.00728
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - categorical_accuracy: 1.0000 - loss: 0.0403 - val_categorical_accuracy: 1.0000 - val_loss: 0.0372 - learning_rate: 1.0000e-04
# Epoch 19/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9897 - loss: 0.0351
# Epoch 19: val_loss did not improve from 0.00728
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 327s 9s/step - categorical_accuracy: 0.9898 - loss: 0.0350 - val_categorical_accuracy: 0.9732 - val_loss: 0.1240 - learning_rate: 1.0000e-04
# Epoch 20/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:03 7s/step - categorical_accuracy: 0.9688 - loss: 0.0586
# Epoch 20: val_loss did not improve from 0.00728
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - categorical_accuracy: 0.9688 - loss: 0.0586 - val_categorical_accuracy: 0.9333 - val_loss: 0.2475 - learning_rate: 1.0000e-04
# Epoch 21/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - categorical_accuracy: 0.9923 - loss: 0.0303
# Epoch 21: val_loss did not improve from 0.00728
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 336s 9s/step - categorical_accuracy: 0.9923 - loss: 0.0304 - val_categorical_accuracy: 0.9732 - val_loss: 0.1104 - learning_rate: 1.0000e-04
# Epoch 22/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:33 6s/step - categorical_accuracy: 1.0000 - loss: 0.0067
# Epoch 22: val_loss did not improve from 0.00728
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 16s 299ms/step - categorical_accuracy: 1.0000 - loss: 0.0067 - val_categorical_accuracy: 1.0000 - val_loss: 0.0401 - learning_rate: 1.0000e-05
# Epoch 23/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9977 - loss: 0.0199
# Epoch 23: val_loss did not improve from 0.00728
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 336s 9s/step - categorical_accuracy: 0.9976 - loss: 0.0200 - val_categorical_accuracy: 0.9777 - val_loss: 0.0848 - learning_rate: 1.0000e-05
# Epoch 24/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:41 7s/step - categorical_accuracy: 1.0000 - loss: 0.0104
# Epoch 24: val_loss did not improve from 0.00728
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0104 - val_categorical_accuracy: 0.9333 - val_loss: 0.3486 - learning_rate: 1.0000e-05
# Epoch 25/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9957 - loss: 0.0206
# Epoch 25: val_loss did not improve from 0.00728
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 364s 9s/step - categorical_accuracy: 0.9957 - loss: 0.0206 - val_categorical_accuracy: 0.9732 - val_loss: 0.1049 - learning_rate: 1.0000e-05
# Epoch 26/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:33 6s/step - categorical_accuracy: 0.9688 - loss: 0.0346
# Epoch 26: val_loss improved from 0.00728 to 0.00233, saving model to /content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-26.weights.h5
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - categorical_accuracy: 0.9688 - loss: 0.0346 - val_categorical_accuracy: 1.0000 - val_loss: 0.0023 - learning_rate: 1.0000e-05
# Epoch 27/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9929 - loss: 0.0218
# Epoch 27: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 379s 9s/step - categorical_accuracy: 0.9928 - loss: 0.0219 - val_categorical_accuracy: 0.9732 - val_loss: 0.0977 - learning_rate: 1.0000e-05
# Epoch 28/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:20 6s/step - categorical_accuracy: 1.0000 - loss: 0.0204
# Epoch 28: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0204 - val_categorical_accuracy: 1.0000 - val_loss: 0.0033 - learning_rate: 1.0000e-05
# Epoch 29/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9928 - loss: 0.0300
# Epoch 29: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 326s 9s/step - categorical_accuracy: 0.9929 - loss: 0.0298 - val_categorical_accuracy: 0.9777 - val_loss: 0.0846 - learning_rate: 1.0000e-05
# Epoch 30/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:15 6s/step - categorical_accuracy: 1.0000 - loss: 0.0052
# Epoch 30: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - categorical_accuracy: 1.0000 - loss: 0.0052 - val_categorical_accuracy: 0.9333 - val_loss: 0.1544 - learning_rate: 1.0000e-05
# Epoch 31/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9979 - loss: 0.0162
# Epoch 31: val_loss did not improve from 0.00233
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 332s 9s/step - categorical_accuracy: 0.9979 - loss: 0.0164 - val_categorical_accuracy: 0.9732 - val_loss: 0.0918 - learning_rate: 1.0000e-05
# Epoch 32/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:38 7s/step - categorical_accuracy: 1.0000 - loss: 0.0093
# Epoch 32: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 17s 312ms/step - categorical_accuracy: 1.0000 - loss: 0.0093 - val_categorical_accuracy: 1.0000 - val_loss: 0.0045 - learning_rate: 1.0000e-06
# Epoch 33/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9937 - loss: 0.0241
# Epoch 33: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 329s 9s/step - categorical_accuracy: 0.9937 - loss: 0.0241 - val_categorical_accuracy: 0.9732 - val_loss: 0.0912 - learning_rate: 1.0000e-06
# Epoch 34/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:11 6s/step - categorical_accuracy: 1.0000 - loss: 0.0132
# Epoch 34: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - categorical_accuracy: 1.0000 - loss: 0.0132 - val_categorical_accuracy: 1.0000 - val_loss: 0.0075 - learning_rate: 1.0000e-06
# Epoch 35/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9997 - loss: 0.0104
# Epoch 35: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 373s 9s/step - categorical_accuracy: 0.9997 - loss: 0.0106 - val_categorical_accuracy: 0.9777 - val_loss: 0.0792 - learning_rate: 1.0000e-06
# Epoch 36/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:15 8s/step - categorical_accuracy: 1.0000 - loss: 0.0157
# Epoch 36: val_loss did not improve from 0.00233
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 17s 289ms/step - categorical_accuracy: 1.0000 - loss: 0.0157 - val_categorical_accuracy: 0.9333 - val_loss: 0.1808 - learning_rate: 1.0000e-06
# Epoch 37/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - categorical_accuracy: 0.9964 - loss: 0.0144
# Epoch 37: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 336s 9s/step - categorical_accuracy: 0.9964 - loss: 0.0145 - val_categorical_accuracy: 0.9732 - val_loss: 0.0898 - learning_rate: 1.0000e-07
# Epoch 38/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:25 6s/step - categorical_accuracy: 1.0000 - loss: 0.0288
# Epoch 38: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - categorical_accuracy: 1.0000 - loss: 0.0288 - val_categorical_accuracy: 1.0000 - val_loss: 0.0246 - learning_rate: 1.0000e-07
# Epoch 39/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9962 - loss: 0.0275
# Epoch 39: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 366s 9s/step - categorical_accuracy: 0.9962 - loss: 0.0273 - val_categorical_accuracy: 0.9777 - val_loss: 0.0685 - learning_rate: 1.0000e-07
# Epoch 40/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:20 6s/step - categorical_accuracy: 1.0000 - loss: 0.0077
# Epoch 40: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 15s 285ms/step - categorical_accuracy: 1.0000 - loss: 0.0077 - val_categorical_accuracy: 0.9333 - val_loss: 0.3398 - learning_rate: 1.0000e-07
# Epoch 41/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - categorical_accuracy: 0.9982 - loss: 0.0088
# Epoch 41: val_loss did not improve from 0.00233
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 376s 9s/step - categorical_accuracy: 0.9981 - loss: 0.0090 - val_categorical_accuracy: 0.9777 - val_loss: 0.0799 - learning_rate: 1.0000e-07
# Epoch 42/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:15 8s/step - categorical_accuracy: 1.0000 - loss: 0.0141
# Epoch 42: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 17s 294ms/step - categorical_accuracy: 1.0000 - loss: 0.0141 - val_categorical_accuracy: 0.9333 - val_loss: 0.1719 - learning_rate: 1.0000e-08
# Epoch 43/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9938 - loss: 0.0193
# Epoch 43: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 325s 9s/step - categorical_accuracy: 0.9939 - loss: 0.0193 - val_categorical_accuracy: 0.9732 - val_loss: 0.0909 - learning_rate: 1.0000e-08
# Epoch 44/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3:11 6s/step - categorical_accuracy: 0.9688 - loss: 0.0688
# Epoch 44: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - categorical_accuracy: 0.9688 - loss: 0.0688 - val_categorical_accuracy: 1.0000 - val_loss: 0.0098 - learning_rate: 1.0000e-08
# Epoch 45/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9955 - loss: 0.0167
# Epoch 45: val_loss did not improve from 0.00233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 381s 9s/step - categorical_accuracy: 0.9955 - loss: 0.0167 - val_categorical_accuracy: 0.9777 - val_loss: 0.0810 - learning_rate: 1.0000e-08
# Epoch 46/50
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 4:22 8s/step - categorical_accuracy: 1.0000 - loss: 0.0148
# Epoch 46: val_loss did not improve from 0.00233
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - categorical_accuracy: 1.0000 - loss: 0.0148 - val_categorical_accuracy: 0.9333 - val_loss: 0.1644 - learning_rate: 1.0000e-08
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 26.

# %%
# Convert the Keras model to a TensorFlow Lite model
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TensorFlow Lite model to a file
with open('/content/drive/MyDrive/fypmodel/MobilenetV1/new4/model.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpgta66gef'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_271')
# Output Type:
#   TensorSpec(shape=(None, 8), dtype=tf.float32, name=None)
# Captures:
#   132210173449616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173449264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173453840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173451200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173452080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173457536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173454016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173458064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173458240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173459120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173497184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173496832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173500880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173498240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173499120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173505808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173505456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173509152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173506512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173507392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173578224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173577872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173581920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173579280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173580160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173585616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173585264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173588960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173586320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173587200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173590720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173657152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173661728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173659264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173659616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173666656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173666304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173670000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173667360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173668240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173672288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173771840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173773952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173773248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173774128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173779232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173778880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173782576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173779936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173780816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173785920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173853760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173855872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173786800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173786448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173859920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173859568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173863616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173860976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173861856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173866960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173856576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173867840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173868016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173868896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173972496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173972144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173976192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173973552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173974432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173979536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173969328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173983232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173980592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210173981472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174068688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174068336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174072384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174069744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174070624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174075728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174075376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174079424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174076784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174077664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210174081888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172071424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172068784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172069136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172068256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172074768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172074416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172078464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172075824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172076704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172082160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172083920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172184528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172082688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172082336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172187344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172186992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172191040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172188400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172189280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172194736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172194384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172198080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172195440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172196320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172218000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172217648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172221696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172219056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172219936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172226624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172226272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172229968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172227328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172228208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172317536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172322112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172325280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172323344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172325632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172320352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172412672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172414432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172413552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172413904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172419536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172419184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172423232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172420592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210172421472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210171662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132210171666576: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
import matplotlib.pyplot as plt

def plot_accuracy(history, title):
    """
    Plots training and validation accuracy from the training history.

    Parameters:
    - history: The training history object returned by model.fit().
    - title: The title for the accuracy plot.
    """
    plt.title(title)  # Set the title of the plot
    plt.plot(history.history['categorical_accuracy'], label='train_accuracy')  # Plot training accuracy
    plt.plot(history.history['val_categorical_accuracy'], label='val_accuracy')  # Plot validation accuracy
    plt.ylabel('accuracy')  # Y-axis label
    plt.xlabel('epoch')  # X-axis label
    plt.ylim(0, 1)  # Set y-axis limits from 0 to 1
    plt.legend(loc='best')  # Add a legend to the plot
    plt.show()  # Display the plot

def plot_loss(history, title):
    """
    Plots training and validation loss from the training history.

    Parameters:
    - history: The training history object returned by model.fit().
    - title: The title for the loss plot.
    """
    plt.title(title)  # Set the title of the plot
    plt.plot(history.history['loss'], label='train_loss')  # Plot training loss
    plt.plot(history.history['val_loss'], label='val_loss')  # Plot validation loss
    plt.ylabel('loss')  # Y-axis label
    plt.xlabel('epoch')  # X-axis label
    plt.ylim(0, 1)  # Set y-axis limits from 0 to 1
    plt.legend(loc='best')  # Add a legend to the plot
    plt.show()  # Display the plot

# %%
# Plot training and validation accuracy
plot_accuracy(history, 'Classification Accuracy Plot')

# %%
# Load the model weights from the specified file path
model.load_weights('/content/drive/MyDrive/fypmodel/MobilenetV1/new4/weights/MobileNet_weights-28.weights.h5')

# %%
# Make predictions on the test dataset using the trained model
predictions = model.predict(test_generator, verbose=0)

# Get the index of the highest probability class for each image
y_pred = np.argmax(predictions, axis=1)

# Get the true labels for the images from the test generator
y_true = test_generator.classes

# Retrieve the class names (labels) from the test generator
class_names = list(test_generator.class_indices.keys())

# Print the classification report which includes precision, recall, f1-score, and support
report = classification_report(y_true, y_pred, target_names=class_names)
print("\nClassification Report:")
print(report)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        11
#            1       0.84      1.00      0.92        38
#            2       0.68      0.95      0.79        38
#            3       0.61      0.96      0.75        26
#            4       0.97      1.00      0.99        38
#            5       1.00      0.08      0.15        38
#            6       1.00      1.00      1.00        38
#            7       0.92      0.73      0.81        15
#
#     accuracy                           0.82       242
#    macro avg       0.87      0.83      0.79       242
# weighted avg       0.87      0.82      0.78       242

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

# Generate the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix directly
plot_confusion_matrix(conf_mat=conf_matrix,
                      show_absolute=True,
                      show_normed=True,
                      colorbar=True,
                      class_names=class_names,
                      figsize=(8, 8), #specify figure size here
                      cmap='Blues')

# Set the title and display the plot
plt.title('Confusion Matrix')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from mlxtend.plotting import plot_confusion_matrix

# Compute the confusion matrix using sklearn's metrics module
cm = metrics.confusion_matrix(y_true, y_pred)

# Plot the confusion matrix using mlxtend's `plot_confusion_matrix` function
fig, ax = plot_confusion_matrix( #  Remove the 'ax' argument from the function call
    conf_mat=cm,  # Pass the confusion matrix to the function
    show_absolute=True,  # Display the raw counts of predictions
    show_normed=False,  # Do not normalize the counts
    colorbar=True,  # Include a color bar to show the intensity of the values
    class_names=class_names,  # Provide the names of the classes for labeling
    figsize=(7, 7) # Specify the figure size here instead
)

# Set the title
plt.title('Confusion Matrix')

# Show the plot
plt.show()

# %%
from sklearn.metrics import accuracy_score

# Compute the accuracy of the model
accuracy = accuracy_score(y_true, y_pred)

# Print the accuracy
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8223

# %%
# Predict the classes of the test set
test_generator.reset()  # Reset the generator to ensure it starts from the beginning
predictions = model.predict(test_generator, steps=len(test_generator), verbose=0)  # Predict class probabilities
predicted_classes = np.argmax(predictions, axis=1)  # Convert probabilities to class labels

# True labels
true_classes = test_generator.classes  # Extract true class labels from the test generator

# Calculate accuracy
test_accuracy = accuracy_score(true_classes, predicted_classes)  # Compute accuracy score
print(f'Test Accuracy: {test_accuracy:.4f}')  # Print the accuracy score formatted to four decimal places
# Out:
# Test Accuracy: 0.8223

# %%
# Save the model in HDF5 format
model.save('/content/drive/MyDrive/fypmodel/output_models/lagacymodel.h5')
model.save('/content/drive/MyDrive/fypmodel/output_models/newmodel.keras')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/fypmodel/output_models/newmodel.keras')

# Convert the model to TFLite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model to a file
with open('/content/drive/MyDrive/fypmodel/output_models/model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 85 variables whereas the saved optimizer has 168 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Saved artifact at '/tmp/tmp4r5cq7gf'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_3')
# Output Type:
#   TensorSpec(shape=(1, None, 8), dtype=tf.float32, name=None)
# Captures:
#   132209792486912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792495008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792498880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792491136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792494304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792471056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792468064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792475280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792470704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792469472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792477040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792476336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792481440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792477568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792478448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792779888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792778832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792783056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792780416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792781296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792786400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792785696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792790800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792786928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792787808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792792912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792830272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792830800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792829392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792827808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792832384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792831680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792836784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792832912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792833792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792840128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792839776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792843296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792841008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792843120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792912368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792911664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792915536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792912896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792913776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792918880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792918000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792923280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792919408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792920288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792924688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792237088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792233040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792231104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792236384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792229696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792231984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792226352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792229520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792229344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792222832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792731440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792731968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792221248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792729504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792733552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792732672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792737952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792734080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792734960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792740064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792739360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792744464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792740592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209792741472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791026096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791025216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791029088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791026800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791027504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791034544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791031552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791036480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791034368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791033136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791040352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791093216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791093744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791041056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791091280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791095328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791094624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791099728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791095856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791096736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791101840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791100960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791106240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791102368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791103248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791190992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791189408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791193456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791190640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791191520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791197152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791197680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791201024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791196272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791198736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791202256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791355536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791356064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791204896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791353072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791358880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791357824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791363280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791359408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791360288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791365392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791364688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791360464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791365920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791366800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791454016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791453136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791457184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791454544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791455424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791460528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791459824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791464928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791461056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791461936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791862560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132209791865552: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
import numpy as np

# Load the TFLite model and allocate tensors
interpreter = tf.lite.Interpreter(model_path='/content/drive/MyDrive/fypmodel/output_models/model.tflite')
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Test the model with some data
test_image = np.random.random(size=(1, IMAGE_SIZE, IMAGE_SIZE, 3)).astype(np.float32)
interpreter.set_tensor(input_details[0]['index'], test_image)
interpreter.invoke()
output = interpreter.get_tensor(output_details[0]['index'])
print(output)
# Out:
# [[[2.3250252e-02 4.7079520e-03 2.2562391e-03 8.9223858e-04 1.8787054e-04
#    3.9787987e-01 5.1429915e-01 5.6526456e-02]]]
